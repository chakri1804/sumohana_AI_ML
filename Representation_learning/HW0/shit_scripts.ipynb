# %%
import cv2

# %%
img = cv2.imread('Cyberpunk-1.jpg')
img = cv2.resize(img,(432,768))
cv2.imwrite('Cyberpunk_smool.jpg',img)
img.shape
# Out:
# (768, 432, 3)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
cent = []
for i in range(3):
    k = np.mean(np.mean(img,axis=0),axis=0) + np.random.uniform(-100,100,(3,))
    cent.append(k)
print(cent)
# Out:
# [array([224.35643848, 101.79096009, 192.1506426 ]), array([176.77912612, 151.8013046 , 132.54131603]), array([167.90815425, 124.50102765, 163.06899574])]

# %%
from scipy import stats
from collections import Counter

# %%
while(True):
    print(img[int(np.random.normal(len(img)/2,len(img)/10))][int(np.random.normal(len(img[0])/2,len(img)/10))])
# Out:
# [252   0   0]
# [  3 255 125]
# [  0 254  93]
# [ 26 230   1]
# [  0 224 239]
# [221   2 152]
# [103   0 208]
# [144   0  63]
# [ 22  21 229]
# [157   0  90]
# [  0 254 147]
# [ 95 155   4]
# [  1  12 255]
# [  1 169 254]
# [  0   2 255]
# [237   9   0]
# [  0 254 108]
# [240  15   0]
# [231  21   4]
# [128   0  75]
# [  4 205 255]
# [  3 247 251]
# [143   0 190]
# [176   0  98]
# [203   1  32]
# [  3 227 252]
# [  0 109 254]
# [  1 254 239]
# [ 83 169   1]
# [187   0 169]
# [228   0 126]
# [ 43   2 231]
# [246  11   0]
# [194   0 166]
# [252   2   1]
# [  1 216 255]
# [214  40   0]
# [132 124   0]
# [181   0 103]
# [175  12 172]
# [231   0 125]
# [  0 239 255]
# [118   0 200]
# [  0 254 207]
# [205   0  28]
# [144   5  82]
# [254   3 135]
# [  0 128 253]
# [136   0 194]
# [162   0  58]
# [132   1  72]
# [  2 220 254]
# [167   0  93]
# [  0  86 254]
# [136   0  78]
# [  3  96 255]
# [145   2  59]
# [  0 197 254]
# [180   0 101]
# [177   0  97]
# [  0 255  97]
# [225   1 150]
# ...
